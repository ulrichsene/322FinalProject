# %%
import importlib
import mysklearn2.mypytable2
importlib.reload(mysklearn2.mypytable2)
from mysklearn2.mypytable2 import MyPyTable

import utils2
importlib.reload(utils2)
import plot_utils2
importlib.reload(plot_utils2)
# Out:
# <module 'plot_utils2' from '/home/322FinalProject/plot_utils2.py'>

# %%
utils2.clean_and_save_data("input_data2/diabetes_prediction_dataset2.csv", "output_data/cleaned_diabetes_data.csv")
# Out:
# Before cleaning - Rows: 100000, Columns: 9
# After cleaning - Rows: 64184, Columns: 9

# %%
plot_utils2.plot_diabetes_status()

# %%
plot_utils2.plot_gender_distribution()

# %%
plot_utils2.plot_diabetes_by_gender()
